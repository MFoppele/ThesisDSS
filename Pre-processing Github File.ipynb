# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_excel(r'x') #Loading the data

# %%
print(len(df['Spoken'].unique())) #Test to see how long the aligned data set should be
# Out:
# 59035

# %%
aligned_data = df.groupby('Spoken')['Sign'].apply(lambda group_series: group_series.tolist()).reset_index() #Allocates all the snippits to their correct counterpart in list format

# %%
mini = aligned_data.head(50) #Creates a size 50 sample for quick testing of other preprocessing codes

# %%
for index in range(len(mini['Sign'])):
  mini['Sign'][index] = [word for word in mini['Sign'][index] if not(pd.isnull(word)) == True] #Removing all the nan's from the data https://www.pythonpool.com/python-remove-nan-from-list/
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#print(mini)

# %%
for index in range(len(mini['Sign'])):
  mini['Sign'][index] = ' '.join([str(i) for i in mini['Sign'][index]]) #Transforms the lists into strings
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
regex = re.compile('[^a-zA-ZäöüïëÄÜÖÏËß]') #Removing non alphabetic characters, excluding e.g. ä which is a common letter in German https://stackoverflow.com/questions/22520932/python-remove-all-non-alphabet-chars-from-string

# %%
for index in range(len(mini['Sign'])):
  mini['Sign'][index] = regex.sub(' ', mini['Sign'][index]).lower() #Loop to implement regex on all sentences in Sign column, makes letters lowercase
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for index in range(len(mini['Spoken'])):
  mini['Spoken'][index] = regex.sub(' ', mini['Spoken'][index]).lower() #Loop to implement regex on all sentences in spoken column, makes letters lowercase
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for index in range(len(mini['Spoken'])):
  mini['Spoken'][index] = mini['Spoken'][index].split() #Remove all spaces by returning plain text back to lists, this will also be used to remove words consisting of one letter (there are not any in German)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for index in range(len(mini['Sign'])):
  mini['Sign'][index] = mini['Sign'][index].split() #Remove all spaces by returning plain text back to lists, this will also be used to remove words consisting of one letter (there are not any in German)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for index in range(len(mini['Sign'])):
  for subindex in range(len(mini['Sign'][index])):
     mini['Sign'][index] = [i for i in mini['Sign'][index] if len(i) > 1] #Remove all words <= 1 from sign column
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for index in range(len(mini['Spoken'])):
  for subindex in range(len(mini['Spoken'][index])):
     mini['Spoken'][index] = [i for i in mini['Spoken'][index] if len(i) > 1] #Remove all words <= 1 from Spoken column
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for index in range(len(mini['Sign'])):
  mini['Sign'][index] = ' '.join([str(i) for i in mini['Sign'][index]]) #Back to plain text
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for index in range(len(mini['Spoken'])):
  mini['Spoken'][index] = ' '.join([str(i) for i in mini['Spoken'][index]]) #Back to plain text
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
mini['Spoken'].replace('', np.nan, inplace=True) #Replacing the empty fields with 'NaN'
mini['Sign'].replace('', np.nan, inplace=True) #Replacing the empty fields with 'NaN'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
mini.dropna(subset=['Spoken'], inplace=True) #Drop all rows containing NaN
mini.dropna(subset=['Sign'], inplace=True) #Drop all rows containing NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#mini
# Out:
#                                                Spoken                                               Sign
# 0                                    doch das ist gut                                        gest nm gut
# 1   war dann schluss damit in meinem leben war ich...  num einer num zehner ich zusammen mein leben m...
# 2         wurde ich eingeschult war meine einschulung  ich num teen num hunderter num ich umziehen nu...
# 4                      damals in name zum fußballfest                    index fussball fest feier index
# 5                          deine heimat ist also name                                           ich name
# 6   deine heimatregion name ist interessanter als ...  heimat name bereich berg mehr interesse name l...
# 7                                 der heißt name name          index heissen name name name person index
# 8   der kleine name war damals bei mir da er krank...  und index name kommen krank index ich index pf...
# 9                                   er ist einfach zu                                               name
# 10                   er ist so es fällt ihm zu schwer             name index gest abwinken gest abwinken
# 11                                        es war name                                              index
# 12  herr name ist mir um den hals gefallen das hat...                  index umarmen ich zurück gest off
# 13          ihr vater war früher in name bankdirektor  wohnung in wohnung name in vater sein ihr bank...
# 14                                in name interessant                            früh name gest nm index
# 15  in name unterhalb von berlin in der nähe von n...         name berlin unten name name aufwachsen oma
# 16                                               name                                         name index
# 17               name aus hamburg hat einmal gewonnen                    name hamburg gewinnen mal index
# 18                 name aus hamburg hat gewonnen oder                         name oral hamburg gewinnen
# 19                              name begann zu weinen                  stimmt name schneiden muss weinen
# 20                                   name gab mir das                                    name name index
# 21  name hat dann für mich abgesehen und für mich ...                name index ende index antwort index
# 22  name hat den arzt gebeten den kopf hoch zu neh...  ich name bescheid du kopf hoch weil index höre...
# 23  name hat mit dem rauchen aufgehört nach dem krebs                               name name nein krebs
# 24  name hat sich getrennt aber die eltern seiner ...  name jetzt trennen früher taub gehörlos eltern...
# 25                      name ist eben ein kleiner ort                                     name klein ort
# 26                                 name ist gestorben                       name name index tod name tod
# 28                                 name kam dann dazu                       eintreten eintreten gest off
# 29                        name kann das eigentlich ab                            aber name eigentlich ja
# 30                        name kenne ich nicht so gut                                               name
# 31                          name kommt dann nach name  nach ort name name index einsteigen index name...
# 32                          name oder name so hieß er  oral gest nm kopfnicken name name name name index
# 33  name sagte ich solle mich nicht mit denen unte...                               name gebärden schutz
# 34                                 name saß am steuer                                   name auto fahren
# 35  name schaute und sagte mama meine schwester sc...              index index gest ich schwester schrei
# 36  name schnappte sich schnell seine sachen und w...                   index name index gest nach hause
# 37                   name war auch ein freund von mir  index auch freund er sie es gleich ich index i...
# 39  name wurde ja rausgeschmissen ich habe bei düs...  index name index entlassen ich düsseldorf num ...
# 40                   name wurde nach bremen geschickt             ich schicken ich richtung bremen index
# 41                 name bei name war es auch der fall                         name name name gleich fall
# 42              name die halbschwester meiner tochter  protest name name index name index mein tochte...
# 43  name genau ja der war ein gegner von gebärden ...  name name index ja index gebärden feind index ...
# 44                                 name kennst du den                                     name du kennen
# 45                                 name kennst du sie                        list of name name kennen du
# 46  name nein ihr freund hat die information bekommen  name bekommen index lebenspartner index bekomm...
# 47  name oder doch ihr beide doch ich glaube name ...           name du beide führen glauben name führen
# 48                                      name weißt du                                         name index
# 49                                               name                                name name egal oral
